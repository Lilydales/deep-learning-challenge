# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import pandas as pd
import tensorflow as tf
import joblib
import os
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From C:\Users\phamt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=[
    'T9','T13','T12','T2','T25','T14','T29','T15','T17'
]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_higher_than_1_counts = classification_counts[classification_counts>1]
classification_higher_than_1_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace= classification_counts[classification_counts<1883].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']
application_df=pd.get_dummies(application_df,columns=categorical_columns)
application_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y=application_df['IS_SUCCESSFUL'].values
X=application_df.drop(['IS_SUCCESSFUL'], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\phamt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\phamt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\phamt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\phamt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5725 - accuracy: 0.7217
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5560 - accuracy: 0.7303
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5552 - accuracy: 0.7300
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5522 - accuracy: 0.7315
# Epoch 5/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5548 - accuracy: 0.7261 - 324ms/epoch - 1ms/step
# Loss: 0.5548034310340881, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
models_folder = 'models'
os.makedirs(models_folder, exist_ok=True) 
model_filename = os.path.join(models_folder, 'AlphabetSoupCharity.h5')
joblib.dump(fit_model, model_filename)
# Out:
# ['models\\AlphabetSoupCharity.h5']

# %% [markdown]
# ## Optimizing Model

# %%
#Create a new Sequential model
model_optimized = Sequential()

# Add the input layer and first hidden layer
model_optimized.add(Dense(units=128, input_dim=number_input_features, activation='relu'))

# Add additional hidden layers with different optimization methods
model_optimized.add(Dense(units=64, activation='relu'))
model_optimized.add(Dense(units=32, activation='relu'))

# Add the output layer
model_optimized.add(Dense(units=1, activation='sigmoid'))

# Display the model summary
model_optimized.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 128)               5632
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 1)                 33
#
# ...
# Total params: 16001 (62.50 KB)
# Trainable params: 16001 (62.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Stochastic Gradient Descent (SGD)

# %%
# Compile the model with different optimization methods
model_optimized.compile(optimizer=SGD(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with SGD
model_optimized.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.6096 - accuracy: 0.6999 - val_loss: 0.5771 - val_accuracy: 0.7215
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5648 - accuracy: 0.7280 - val_loss: 0.5636 - val_accuracy: 0.7248
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5580 - accuracy: 0.7303 - val_loss: 0.5606 - val_accuracy: 0.7234
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5551 - accuracy: 0.7311 - val_loss: 0.5581 - val_accuracy: 0.7242
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7313 - val_loss: 0.5575 - val_accuracy: 0.7254
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7322 - val_loss: 0.5556 - val_accuracy: 0.7247
# Epoch 7/100
# ...

# %% [markdown]
# ### Adam optimizer

# %%
model_optimized.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with Adam optimizer
model_optimized.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5751 - accuracy: 0.7208 - val_loss: 0.5731 - val_accuracy: 0.7128
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5640 - accuracy: 0.7229 - val_loss: 0.5839 - val_accuracy: 0.7148
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5599 - accuracy: 0.7229 - val_loss: 0.5617 - val_accuracy: 0.7224
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5598 - accuracy: 0.7248 - val_loss: 0.5631 - val_accuracy: 0.7200
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5595 - accuracy: 0.7271 - val_loss: 0.5543 - val_accuracy: 0.7247
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5568 - accuracy: 0.7280 - val_loss: 0.5696 - val_accuracy: 0.7252
# Epoch 7/100
# ...

# %% [markdown]
# ### RMSprop optimizer

# %%
model_optimized.compile(optimizer=RMSprop(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with RMSprop optimizer
model_optimized.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5567 - accuracy: 0.7187 - val_loss: 0.5704 - val_accuracy: 0.7148
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5584 - accuracy: 0.7195 - val_loss: 0.5641 - val_accuracy: 0.7156
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5604 - accuracy: 0.7194 - val_loss: 0.5651 - val_accuracy: 0.7150
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5603 - accuracy: 0.7185 - val_loss: 0.5594 - val_accuracy: 0.7153
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5603 - accuracy: 0.7182 - val_loss: 0.5678 - val_accuracy: 0.7149
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5597 - accuracy: 0.7173 - val_loss: 0.5777 - val_accuracy: 0.7155
# Epoch 7/100
# ...

# %%
# Export our model to HDF5 file
models_folder = 'models'
os.makedirs(models_folder, exist_ok=True) 
model_filename = os.path.join(models_folder, 'AlphabetSoupCharity_Optimisation.h5')
joblib.dump(model_optimized, model_filename)
# Out:
# ['models\\AlphabetSoupCharity_Optimisation.h5']
